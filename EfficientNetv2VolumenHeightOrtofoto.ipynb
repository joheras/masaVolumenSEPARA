# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(3)

# %%
df = pd.read_csv('../dataset.csv')

# %%
df = df.drop(df[df.masa<0].index)

# %%
dftrain = df[(df.split=='train') | (df.split=='valid')]
dftest = df[(df.split=='test')]

# %%
# !mkdir ../datasetAltura/train
# !mkdir ../datasetAltura/test

# %%
# import shutil
# from imutils import paths

# %%
# for image in dftrain.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/train'))

# %%
# for image in dftest.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/test'))

# %%
# df.volumen.describe()

# %%
def get_masa(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['masa'])

def get_volumen(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['volumen'])

def is_valid(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='valid'

# %%
class ImageTuple(fastuple):
    @classmethod
    def create(cls, fns): 
        return cls(tuple(PILImage.create(f) for f in fns))
    
    def show(self, ctx=None, **kwargs): 
        t1,t2 = self
        if not isinstance(t1, Tensor) or not isinstance(t2, Tensor) or t1.shape != t2.shape: return ctx
        line = t1.new_zeros(t1.shape[0], t1.shape[1], 10)
        return show_image(torch.cat([t1,line,t2], dim=2), ctx=ctx, **kwargs)

# %%
def ImageTupleBlock(): return TransformBlock(type_tfms=ImageTuple.create, batch_tfms=IntToFloatTensor)

# %%
def get_tuples(files):
    return [[f, Path(str(f).replace('datasetClean','datasetAltura2'))] for f in get_image_files(files)]

# %%
class MyTransform(Transform):
    def __init__(self): self.aug = aug_transforms(size=224,flip_vert=True,max_zoom=1.0)
    def encodes(self, img: PILImage):
        aug_img = self.aug(image=np.array(img))['image']
        return PILImage.create(aug_img)

# %%
def getDataBlock(presize=224,size=224):
    return DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_valid),
                 get_y=get_volumen,
                 item_tfms = [Resize(presize)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
path = Path('../datasetClean/')
trainPath = path/'train'

# %%
db = getDataBlock()
dls = db.dataloaders(trainPath,bs=32)

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    #EarlyStoppingCallback(patience=3),
    SaveModelCallback(fname='efficientnetv2_rw_sVolumeHeightOrtofoto')
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
class SiameseModel(Module):
    def __init__(self, encoder, head):
        self.encoder,self.head = encoder,head
    
    def forward(self, x):
        x1,x2=x
        ftrs = torch.cat([self.encoder(x1), self.encoder(x2)], dim=1)
        return self.head(ftrs)

# %%
model = timm.create_model('efficientnetv2_rw_s',num_classes=1,pretrained=True)

# %%
encoder = nn.Sequential(*list(model.children())[:-2])

# %%
head = create_head(int(7168/2), 1, ps=0.5)
model = SiameseModel(encoder, head)

# %%
def siamese_splitter(model):
    return [params(model.encoder), params(model.head)]

# %%
learn = Learner(dls, model,splitter=siamese_splitter,
                loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks).to_fp16()

# %%
# learn.lr_find()

# %%
learn.fine_tune(1000,base_lr=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th
# Better model found at epoch 34 with valid_loss value: 19.093441009521484.
# Better model found at epoch 36 with valid_loss value: 19.003162384033203.
# Better model found at epoch 41 with valid_loss value: 18.557964324951172.
# Better model found at epoch 45 with valid_loss value: 17.57302474975586.
# Better model found at epoch 48 with valid_loss value: 17.118940353393555.
# Better model found at epoch 49 with valid_loss value: 15.999122619628906.
# Better model found at epoch 50 with valid_loss value: 15.7040376663208.
# Better model found at epoch 51 with valid_loss value: 15.561471939086914.
# Better model found at epoch 52 with valid_loss value: 14.370162963867188.
# Better model found at epoch 53 with valid_loss value: 14.31550407409668.
# Better model found at epoch 87 with valid_loss value: 14.050614356994629.
# Better model found at epoch 88 with valid_loss value: 12.607877731323242.
# Better model found at epoch 89 with valid_loss value: 11.35413646697998.
# Better model found at epoch 100 with valid_loss value: 11.123723030090332.
# Better model found at epoch 102 with valid_loss value: 9.9532470703125.
# Better model found at epoch 104 with valid_loss value: 9.830991744995117.
# Better model found at epoch 109 with valid_loss value: 8.808892250061035.
# Better model found at epoch 110 with valid_loss value: 7.735321998596191.
# Better model found at epoch 111 with valid_loss value: 6.637315273284912.
# Better model found at epoch 115 with valid_loss value: 6.219552516937256.
# Better model found at epoch 116 with valid_loss value: 5.812661170959473.
# Better model found at epoch 121 with valid_loss value: 5.7074055671691895.
# Better model found at epoch 122 with valid_loss value: 5.058451175689697.
# Better model found at epoch 142 with valid_loss value: 4.640571117401123.
# Better model found at epoch 143 with valid_loss value: 4.219522476196289.
# Better model found at epoch 144 with valid_loss value: 4.0213165283203125.
# Better model found at epoch 147 with valid_loss value: 3.342327833175659.
# Better model found at epoch 220 with valid_loss value: 3.195042848587036.
# Better model found at epoch 255 with valid_loss value: 3.0003244876861572.
# Better model found at epoch 267 with valid_loss value: 2.9202768802642822.
# Better model found at epoch 269 with valid_loss value: 2.7468249797821045.
# Better model found at epoch 270 with valid_loss value: 2.705394983291626.
# Better model found at epoch 315 with valid_loss value: 2.5991923809051514.
# Better model found at epoch 318 with valid_loss value: 2.344965696334839.
# Better model found at epoch 327 with valid_loss value: 2.128272771835327.
# Better model found at epoch 492 with valid_loss value: 2.0409984588623047.
# Better model found at epoch 499 with valid_loss value: 1.9993699789047241.

# %%
# learn.load('resnetrs50Masav2HeightOrtofotov2')

# %%
# df[df['image_id']=='datasetClean/br_2022-01-07T10-54-11.tif']

# %%
def is_test(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='test'

# %%
dbtest = DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_test),
                 get_y=get_volumen,
                 item_tfms = [Resize(224)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
dlstest = dbtest.dataloaders(path,bs=16)

# %%
learn.dls=dlstest

# %%
learn.validate()
# Out:
# Better model found at epoch 0 with valid_loss value: 1.18064284324646.
# (#4) [2.0094761848449707,1.18064284324646,1.4175599813461304,2.0094761848449707]

# %%
from sklearn.metrics import mean_absolute_error

# %%
preds,gt = learn.tta()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>

# %%
mean_absolute_error(gt,preds)
# Out:
# 1.239952
