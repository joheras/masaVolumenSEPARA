# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(0)

# %%
df = pd.read_csv('../dataset.csv')

# %%
df = df.drop(df[df.masa<0].index)

# %%
dftrain = df[(df.split=='train') | (df.split=='valid')]
dftest = df[(df.split=='test')]

# %%
# !mkdir ../datasetAltura/train
# !mkdir ../datasetAltura/test

# %%
# import shutil
# from imutils import paths

# %%
# for image in dftrain.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/train'))

# %%
# for image in dftest.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/test'))

# %%
# df.volumen.describe()

# %%
def get_masa(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['masa'])

def get_volumen(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['volumen'])

def is_valid(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='valid'

# %%
class ImageTuple(fastuple):
    @classmethod
    def create(cls, fns): 
        return cls(tuple(PILImage.create(f) for f in fns))
    
    def show(self, ctx=None, **kwargs): 
        t1,t2 = self
        if not isinstance(t1, Tensor) or not isinstance(t2, Tensor) or t1.shape != t2.shape: return ctx
        line = t1.new_zeros(t1.shape[0], t1.shape[1], 10)
        return show_image(torch.cat([t1,line,t2], dim=2), ctx=ctx, **kwargs)

# %%
def ImageTupleBlock(): return TransformBlock(type_tfms=ImageTuple.create, batch_tfms=IntToFloatTensor)

# %%
def get_tuples(files):
    return [[f, Path(str(f).replace('datasetClean','datasetAltura'))] for f in get_image_files(files)]

# %%
import albumentations

# %%
class MyTransform(Transform):
    def __init__(self): self.aug = albumentations.Compose([
            albumentations.HueSaturationValue(
                hue_shift_limit=0.2, 
                sat_shift_limit=0.2, 
                val_shift_limit=0.2, 
                p=0.5
            ),
            albumentations.VerticalFlip(p=0.5),
            albumentations.HorizontalFlip(p=0.5),
            albumentations.CoarseDropout(p=0.5),
            albumentations.Cutout(p=0.5)
        ])
    def encodes(self, img: PILImage):
        aug_img = self.aug(image=np.array(img))['image']
        return PILImage.create(aug_img)

# %%
def getDataBlock(presize=512,size=512):
    return DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_valid),
                 get_y=get_masa,
                 item_tfms = [Resize(presize)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
path = Path('../datasetClean/')
trainPath = path/'train'

# %%
db = getDataBlock()
dls = db.dataloaders(trainPath,bs=8)
# Out:
# /home/jonathan/.virtualenvs/segmentation/lib/python3.6/site-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    #EarlyStoppingCallback(patience=3),
    SaveModelCallback(fname='resnet50Masav2HeightOrtofoto512')
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
class SiameseModel(Module):
    def __init__(self, encoder, head):
        self.encoder,self.head = encoder,head
    
    def forward(self, x):
        x1,x2=x
        ftrs = torch.cat([self.encoder(x1), self.encoder(x2)], dim=1)
        return self.head(ftrs)

# %%
encoder = create_body(resnet50, cut=-2)

# %%
head = create_head(4096, 1, ps=0.5)
model = SiameseModel(encoder, head)

# %%
def siamese_splitter(model):
    return [params(model.encoder), params(model.head)]

# %%
learn = Learner(dls, model,splitter=siamese_splitter,
                loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks).to_fp16()

# %%
# learn.lr_find()

# %%
learn.fine_tune(1000,base_lr=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>109150.015625</td>
#       <td>125049.437500</td>
#       <td>284.884705</td>
#       <td>353.623291</td>
#       <td>125049.437500</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 125049.4375.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>103438.640625</td>
#       <td>124013.890625</td>
#       <td>282.713074</td>
#       <td>352.156097</td>
#       <td>124013.890625</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>106159.382812</td>
#       <td>123760.125000</td>
#       <td>282.458069</td>
#       <td>351.795563</td>
#       <td>123760.125000</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>105982.289062</td>
#       <td>123208.867188</td>
#       <td>281.790100</td>
#       <td>351.011200</td>
#       <td>123208.867188</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>104284.539062</td>
#       <td>123391.179688</td>
#       <td>282.227905</td>
#       <td>351.270813</td>
#       <td>123391.179688</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>104636.375000</td>
#       <td>123155.289062</td>
#       <td>281.917023</td>
#       <td>350.934875</td>
#       <td>123155.289062</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>103263.460938</td>
#       <td>121891.757812</td>
#       <td>279.547485</td>
#       <td>349.130005</td>
#       <td>121891.757812</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>103165.492188</td>
#       <td>121321.289062</td>
#       <td>278.896881</td>
#       <td>348.312042</td>
#       <td>121321.289062</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>101000.453125</td>
#       <td>121138.757812</td>
#       <td>278.525177</td>
#       <td>348.049927</td>
#       <td>121138.757812</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>102482.359375</td>
#       <td>122310.117188</td>
#       <td>281.312653</td>
#       <td>349.728638</td>
#       <td>122310.117188</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>102921.976562</td>
#       <td>121069.421875</td>
#       <td>278.534241</td>
#       <td>347.950287</td>
#       <td>121069.421875</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>102158.171875</td>
#       <td>121245.187500</td>
#       <td>278.739594</td>
#       <td>348.202789</td>
#       <td>121245.187500</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>102619.843750</td>
#       <td>120915.562500</td>
#       <td>278.781860</td>
#       <td>347.729156</td>
#       <td>120915.562500</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>102030.093750</td>
#       <td>121503.546875</td>
#       <td>279.723572</td>
#       <td>348.573608</td>
#       <td>121503.546875</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>101604.179688</td>
#       <td>120153.367188</td>
#       <td>277.011688</td>
#       <td>346.631470</td>
#       <td>120153.367188</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>100309.148438</td>
#       <td>119680.914062</td>
#       <td>276.163147</td>
#       <td>345.949280</td>
#       <td>119680.914062</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>100364.757812</td>
#       <td>119645.234375</td>
#       <td>276.510590</td>
#       <td>345.897736</td>
#       <td>119645.234375</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>99752.976562</td>
#       <td>118407.929688</td>
#       <td>274.346039</td>
#       <td>344.104523</td>
#       <td>118407.929688</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>99846.625000</td>
#       <td>117617.171875</td>
#       <td>272.674286</td>
#       <td>342.953613</td>
#       <td>117617.171875</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>99474.281250</td>
#       <td>118529.382812</td>
#       <td>274.595184</td>
#       <td>344.280945</td>
#       <td>118529.382812</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>99887.648438</td>
#       <td>117926.804688</td>
#       <td>273.444122</td>
#       <td>343.404694</td>
#       <td>117926.804688</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>98669.054688</td>
#       <td>116786.609375</td>
#       <td>271.401428</td>
#       <td>341.740570</td>
#       <td>116786.609375</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>96946.171875</td>
#       <td>117209.773438</td>
#       <td>271.892761</td>
#       <td>342.359161</td>
#       <td>117209.773438</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>97686.968750</td>
#       <td>116451.039062</td>
#       <td>270.643341</td>
#       <td>341.249237</td>
#       <td>116451.039062</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>96763.085938</td>
#       <td>116758.703125</td>
#       <td>270.987640</td>
#       <td>341.699707</td>
#       <td>116758.703125</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>97234.351562</td>
#       <td>115795.140625</td>
#       <td>269.723114</td>
#       <td>340.286865</td>
#       <td>115795.140625</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>95861.554688</td>
#       <td>115777.734375</td>
#       <td>269.738739</td>
#       <td>340.261261</td>
#       <td>115777.734375</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>95547.070312</td>
#       <td>115212.421875</td>
#       <td>269.133850</td>
#       <td>339.429535</td>
#       <td>115212.421875</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>94230.953125</td>
#       <td>114736.210938</td>
#       <td>268.177094</td>
#       <td>338.727325</td>
#       <td>114736.210938</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>94666.414062</td>
#       <td>114316.687500</td>
#       <td>267.097565</td>
#       <td>338.107513</td>
#       <td>114316.687500</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>94300.648438</td>
#       <td>114046.687500</td>
#       <td>267.002411</td>
#       <td>337.707977</td>
#       <td>114046.687500</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>93889.398438</td>
#       <td>112471.804688</td>
#       <td>264.061859</td>
#       <td>335.368164</td>
#       <td>112471.804688</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>94050.804688</td>
#       <td>112758.335938</td>
#       <td>264.586121</td>
#       <td>335.795105</td>
#       <td>112758.335938</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>94339.273438</td>
#       <td>112555.312500</td>
#       <td>264.332489</td>
#       <td>335.492645</td>
#       <td>112555.312500</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>93536.343750</td>
#       <td>110914.179688</td>
#       <td>261.042877</td>
#       <td>333.037811</td>
#       <td>110914.179688</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>94022.031250</td>
#       <td>112494.507812</td>
#       <td>264.816589</td>
#       <td>335.402008</td>
#       <td>112494.507812</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>91935.593750</td>
#       <td>108440.687500</td>
#       <td>256.392761</td>
#       <td>329.303345</td>
#       <td>108440.687500</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>90895.023438</td>
#       <td>109911.992188</td>
#       <td>259.547913</td>
#       <td>331.529785</td>
#       <td>109911.992188</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>90730.492188</td>
#       <td>108961.132812</td>
#       <td>257.858185</td>
#       <td>330.092590</td>
#       <td>108961.132812</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>88506.312500</td>
#       <td>107860.367188</td>
#       <td>256.031708</td>
#       <td>328.421021</td>
#       <td>107860.367188</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>87464.078125</td>
#       <td>108509.437500</td>
# Better model found at epoch 0 with valid_loss value: 124013.890625.
# Better model found at epoch 1 with valid_loss value: 123760.125.
# Better model found at epoch 2 with valid_loss value: 123208.8671875.
# Better model found at epoch 4 with valid_loss value: 123155.2890625.
# Better model found at epoch 5 with valid_loss value: 121891.7578125.
# Better model found at epoch 6 with valid_loss value: 121321.2890625.
# Better model found at epoch 7 with valid_loss value: 121138.7578125.
# Better model found at epoch 9 with valid_loss value: 121069.421875.
# Better model found at epoch 11 with valid_loss value: 120915.5625.
# Better model found at epoch 13 with valid_loss value: 120153.3671875.
# Better model found at epoch 14 with valid_loss value: 119680.9140625.
# Better model found at epoch 15 with valid_loss value: 119645.234375.
# Better model found at epoch 16 with valid_loss value: 118407.9296875.
# Better model found at epoch 17 with valid_loss value: 117617.171875.
# Better model found at epoch 20 with valid_loss value: 116786.609375.
# Better model found at epoch 22 with valid_loss value: 116451.0390625.
# Better model found at epoch 24 with valid_loss value: 115795.140625.
# Better model found at epoch 25 with valid_loss value: 115777.734375.
# Better model found at epoch 26 with valid_loss value: 115212.421875.
# Better model found at epoch 27 with valid_loss value: 114736.2109375.
# Better model found at epoch 28 with valid_loss value: 114316.6875.
# Better model found at epoch 29 with valid_loss value: 114046.6875.
# Better model found at epoch 30 with valid_loss value: 112471.8046875.
# Better model found at epoch 33 with valid_loss value: 110914.1796875.
# Better model found at epoch 35 with valid_loss value: 108440.6875.
# Better model found at epoch 38 with valid_loss value: 107860.3671875.
# Better model found at epoch 42 with valid_loss value: 104824.578125.
# Better model found at epoch 46 with valid_loss value: 102980.609375.
# Better model found at epoch 47 with valid_loss value: 101544.484375.
# Better model found at epoch 49 with valid_loss value: 100525.1015625.
# Better model found at epoch 51 with valid_loss value: 97593.3125.
# Better model found at epoch 52 with valid_loss value: 96626.6953125.
# Better model found at epoch 53 with valid_loss value: 95123.1796875.
# Better model found at epoch 55 with valid_loss value: 94781.109375.
# Better model found at epoch 56 with valid_loss value: 92981.453125.
# Better model found at epoch 57 with valid_loss value: 92782.859375.
# Better model found at epoch 58 with valid_loss value: 90566.140625.
# Better model found at epoch 59 with valid_loss value: 89985.6875.
# Better model found at epoch 60 with valid_loss value: 89467.375.
# Better model found at epoch 61 with valid_loss value: 86698.6953125.
# Better model found at epoch 62 with valid_loss value: 85008.078125.
# Better model found at epoch 64 with valid_loss value: 82430.5546875.
# Better model found at epoch 66 with valid_loss value: 79557.3125.
# Better model found at epoch 68 with valid_loss value: 79112.2890625.
# Better model found at epoch 69 with valid_loss value: 77530.3046875.
# Better model found at epoch 70 with valid_loss value: 76770.609375.
# Better model found at epoch 71 with valid_loss value: 74524.984375.
# Better model found at epoch 76 with valid_loss value: 72312.2890625.
# Better model found at epoch 77 with valid_loss value: 70239.765625.
# Better model found at epoch 78 with valid_loss value: 69086.171875.
# Better model found at epoch 79 with valid_loss value: 66344.3515625.
# Better model found at epoch 80 with valid_loss value: 61363.58984375.
# Better model found at epoch 81 with valid_loss value: 60639.51171875.
# Better model found at epoch 84 with valid_loss value: 57941.08984375.
# Better model found at epoch 85 with valid_loss value: 55415.07421875.
# Better model found at epoch 86 with valid_loss value: 53592.13671875.
# Better model found at epoch 89 with valid_loss value: 51857.76171875.
# Better model found at epoch 90 with valid_loss value: 50993.0234375.
# Better model found at epoch 93 with valid_loss value: 49367.00390625.
# Better model found at epoch 94 with valid_loss value: 48250.35546875.
# Better model found at epoch 95 with valid_loss value: 47888.7109375.
# Better model found at epoch 96 with valid_loss value: 43420.8828125.
# Better model found at epoch 97 with valid_loss value: 42518.37890625.
# Better model found at epoch 98 with valid_loss value: 41209.30859375.
# Better model found at epoch 100 with valid_loss value: 40823.98828125.
# Better model found at epoch 101 with valid_loss value: 40763.59765625.
# Better model found at epoch 102 with valid_loss value: 38141.84375.
# Better model found at epoch 103 with valid_loss value: 37715.1328125.
# Better model found at epoch 104 with valid_loss value: 36674.63671875.
# Better model found at epoch 107 with valid_loss value: 36033.5859375.
# Better model found at epoch 110 with valid_loss value: 36015.6484375.
# Better model found at epoch 111 with valid_loss value: 35477.734375.
# Better model found at epoch 112 with valid_loss value: 34506.4453125.
# Better model found at epoch 113 with valid_loss value: 33700.47265625.
# Better model found at epoch 114 with valid_loss value: 33184.4765625.
# Better model found at epoch 115 with valid_loss value: 32382.27734375.
# Better model found at epoch 116 with valid_loss value: 31658.916015625.
# Better model found at epoch 119 with valid_loss value: 31298.396484375.
# Better model found at epoch 120 with valid_loss value: 30909.67578125.
# Better model found at epoch 122 with valid_loss value: 30014.783203125.
# Better model found at epoch 123 with valid_loss value: 28407.31640625.
# Better model found at epoch 124 with valid_loss value: 26774.958984375.
# Better model found at epoch 275 with valid_loss value: 26000.904296875.
# Better model found at epoch 360 with valid_loss value: 25271.345703125.
# Better model found at epoch 364 with valid_loss value: 25048.99609375.
# Better model found at epoch 380 with valid_loss value: 24325.087890625.
# Better model found at epoch 615 with valid_loss value: 24083.90625.
# Better model found at epoch 620 with valid_loss value: 23884.09375.
# Better model found at epoch 794 with valid_loss value: 23303.009765625.
# Better model found at epoch 884 with valid_loss value: 22605.998046875.

# %%
# learn.load('resnet50Masav2HeightOrtofoto')

# %%
def is_test(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='test'

# %%
dbtest = DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_test),
                 get_y=get_masa,
                 item_tfms = [Resize(512)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
dlstest = dbtest.dataloaders(path,bs=16)

# %%
learn.dls=dlstest

# %%
learn.validate()
# Out:
# Better model found at epoch 0 with valid_loss value: 120.87841033935547.
# (#4) [20232.87890625,120.87841033935547,142.24232482910156,20232.87890625]

# %%
from sklearn.metrics import mean_absolute_error

# %%
preds,gt = learn.tta()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>

# %%
mean_absolute_error(gt,preds)
# Out:
# 121.49381
