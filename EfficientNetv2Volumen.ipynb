# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(0)

# %%
df = pd.read_csv('../dataset.csv')

# %%
df = df.drop(df[df.masa<0].index)

# %%
dftrain = df[(df.split=='train') | (df.split=='valid')]
dftest = df[(df.split=='test')]

# %%
# !mkdir ../datasetClean/train
# !mkdir ../datasetClean/test

# %%
# import shutil
# from imutils import paths

# %%
# for image in dftrain.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetClean'),
#                 image.replace('datasetClean','../datasetClean/train'))

# %%
# for image in dftest.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetClean'),
#                 image.replace('datasetClean','../datasetClean/test'))

# %%
# df.volumen.describe()

# %%
def get_masa(f):
    return float(df[df['image_id']=='datasetClean/'+f.name]['masa'])

def get_volumen(f):
    return float(df[df['image_id']=='datasetClean/'+f.name]['volumen'])

def is_valid(f):
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='valid'

# %%
def getDataBlock(presize=512,size=512):
    return DataBlock(blocks = (ImageBlock, RegressionBlock()),
                 get_items=get_image_files, 
                 splitter=FuncSplitter(is_valid),
                 get_y=get_volumen,
                 item_tfms = Resize(presize),
                 batch_tfms=[*aug_transforms(size=size,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)])

# %%
path = Path('../datasetClean/')
trainPath = path/'train'

# %%
db = getDataBlock()
dls = db.dataloaders(trainPath,bs=8)

# %%
dls.show_batch()

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    #EarlyStoppingCallback(patience=3),
    SaveModelCallback(fname='efficientnetv2_rw_s_Volumen')
]

# %%
from fastai.metrics import mae

# %%
learn = Learner(dls, timm.create_model('efficientnetv2_rw_s',num_classes=1,pretrained=True),
                loss_func=MSELossFlat(), metrics=mae,cbs=callbacks).to_fp16()

# %%
# learn.lr_find()

# %%
learn.fine_tune(1000,base_lr=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>14.866751</td>
#       <td>9.655169</td>
#       <td>2.560837</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 9.655169486999512.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.887201</td>
#       <td>2.312923</td>
#       <td>1.173068</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.403313</td>
#       <td>1.700356</td>
#       <td>1.140939</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.042428</td>
#       <td>1.066671</td>
#       <td>0.800193</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.284191</td>
#       <td>0.791759</td>
#       <td>0.711585</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.838408</td>
#       <td>0.945263</td>
#       <td>0.799419</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.521043</td>
#       <td>0.759441</td>
#       <td>0.669205</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.286838</td>
#       <td>0.598328</td>
#       <td>0.658781</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.086606</td>
#       <td>0.843163</td>
#       <td>0.643974</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.997164</td>
#       <td>0.921238</td>
#       <td>0.772432</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.090906</td>
#       <td>0.565968</td>
#       <td>0.580070</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.938553</td>
#       <td>0.507502</td>
#       <td>0.516012</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.051451</td>
#       <td>0.835109</td>
#       <td>0.760086</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.940760</td>
#       <td>0.630302</td>
#       <td>0.610553</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.788397</td>
#       <td>0.589260</td>
#       <td>0.622016</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.710695</td>
#       <td>0.606518</td>
#       <td>0.663585</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.643790</td>
#       <td>0.958770</td>
#       <td>0.854800</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.737639</td>
#       <td>0.621494</td>
#       <td>0.634326</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.908594</td>
#       <td>0.922734</td>
#       <td>0.725930</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.762217</td>
#       <td>0.451536</td>
#       <td>0.504405</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.678905</td>
#       <td>0.417320</td>
#       <td>0.493903</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.645115</td>
#       <td>0.396100</td>
#       <td>0.509790</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.589733</td>
#       <td>0.544131</td>
#       <td>0.579045</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.544162</td>
#       <td>0.502669</td>
#       <td>0.575020</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.544032</td>
#       <td>0.653803</td>
#       <td>0.683732</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.578711</td>
#       <td>0.600836</td>
#       <td>0.656895</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.518531</td>
#       <td>0.519703</td>
#       <td>0.573136</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.496729</td>
#       <td>0.542545</td>
#       <td>0.542469</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.494087</td>
#       <td>0.432142</td>
#       <td>0.474848</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.448118</td>
#       <td>0.438495</td>
#       <td>0.548633</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.492965</td>
#       <td>0.371925</td>
#       <td>0.476934</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.439160</td>
#       <td>0.255897</td>
#       <td>0.420251</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.444319</td>
#       <td>0.767556</td>
#       <td>0.651206</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.426586</td>
#       <td>0.334837</td>
#       <td>0.458631</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.380567</td>
#       <td>0.433425</td>
#       <td>0.520039</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.392050</td>
#       <td>0.442318</td>
#       <td>0.535516</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.339688</td>
#       <td>0.403504</td>
#       <td>0.527358</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.345109</td>
#       <td>0.565670</td>
#       <td>0.638950</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.351193</td>
#       <td>0.566025</td>
#       <td>0.612676</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.362929</td>
#       <td>0.521068</td>
#       <td>0.581589</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.349724</td>
#       <td>0.744302</td>
#       <td>0.709144</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.390641</td>
#       <td>0.428060</td>
#       <td>0.486857</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.356838</td>
#       <td>0.456695</td>
#       <td>0.541866</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.357280</td>
#       <td>0.409648</td>
#       <td>0.515741</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.315425</td>
#       <td>0.460886</td>
#       <td>0.523919</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.292582</td>
#       <td>0.491689</td>
#       <td>0.560346</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.309225</td>
#       <td>0.405226</td>
#       <td>0.523270</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.318073</td>
#       <td>0.443095</td>
#       <td>0.560805</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.270065</td>
#       <td>0.359414</td>
#       <td>0.469732</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.281457</td>
#       <td>0.430568</td>
#       <td>0.499052</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.296495</td>
#       <td>0.475227</td>
#       <td>0.550412</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.323032</td>
#       <td>0.369993</td>
#       <td>0.469384</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.284410</td>
#       <td>0.446656</td>
#       <td>0.516655</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.272990</td>
#       <td>0.404834</td>
#       <td>0.505146</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.288386</td>
#       <td>0.337373</td>
#       <td>0.471096</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.292589</td>
#       <td>0.380808</td>
#       <td>0.497705</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.257557</td>
#       <td>0.315093</td>
#       <td>0.440109</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.261156</td>
#       <td>0.468386</td>
#       <td>0.536727</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.221875</td>
#       <td>0.350424</td>
#       <td>0.475068</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.231356</td>
#       <td>0.357133</td>
#       <td>0.451791</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.243946</td>
#       <td>0.541878</td>
#       <td>0.621643</td>
#       <td>00:09<
# Better model found at epoch 0 with valid_loss value: 2.3129231929779053.
# Better model found at epoch 1 with valid_loss value: 1.700355887413025.
# Better model found at epoch 2 with valid_loss value: 1.0666714906692505.
# Better model found at epoch 3 with valid_loss value: 0.79175865650177.
# Better model found at epoch 5 with valid_loss value: 0.7594406008720398.
# Better model found at epoch 6 with valid_loss value: 0.5983276963233948.
# Better model found at epoch 9 with valid_loss value: 0.5659676194190979.
# Better model found at epoch 10 with valid_loss value: 0.5075017213821411.
# Better model found at epoch 18 with valid_loss value: 0.4515356421470642.
# Better model found at epoch 19 with valid_loss value: 0.41732048988342285.
# Better model found at epoch 20 with valid_loss value: 0.3960998058319092.
# Better model found at epoch 29 with valid_loss value: 0.37192538380622864.
# Better model found at epoch 30 with valid_loss value: 0.25589704513549805.
# Better model found at epoch 107 with valid_loss value: 0.22170580923557281.
# Better model found at epoch 181 with valid_loss value: 0.21044442057609558.
# Better model found at epoch 494 with valid_loss value: 0.2007053643465042.

# %%
learn.load('efficientnetv2_rw_s_Volumen')
# Out:
# /home/jonathan/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")

# %%
def is_test(f):
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='test'

# %%
dbtest = DataBlock(blocks = (ImageBlock, RegressionBlock()),
                 get_items=get_image_files, 
                 splitter=FuncSplitter(is_test),
                 get_y=get_volumen,
                 item_tfms = Resize(512),
                 batch_tfms=[*aug_transforms(size=512,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)])

# %%
dlstest = dbtest.dataloaders(path,bs=8)

# %%
learn.dls=dlstest

# %%
learn.validate()
# Out:
# Better model found at epoch 0 with valid_loss value: 0.42232397198677063.
# (#2) [0.7404224872589111,0.42232397198677063]

# %%
from sklearn.metrics import mean_absolute_error

# %%
preds,gt = learn.get_preds()

# %%
mean_absolute_error(gt,preds)
# Out:
# 0.422324

# %%
preds,gt = learn.tta()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>

# %%
mean_absolute_error(gt,preds)
# Out:
# 0.4057721
