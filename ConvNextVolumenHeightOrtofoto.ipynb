# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(0)

# %%
df = pd.read_csv('../dataset.csv')

# %%
df = df.drop(df[df.masa<0].index)

# %%
dftrain = df[(df.split=='train') | (df.split=='valid')]
dftest = df[(df.split=='test')]

# %%
# !mkdir ../datasetAltura/train
# !mkdir ../datasetAltura/test

# %%
# import shutil
# from imutils import paths

# %%
# for image in dftrain.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/train'))

# %%
# for image in dftest.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/test'))

# %%
# df.volumen.describe()

# %%
def get_masa(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['masa'])

def get_volumen(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['volumen'])

def is_valid(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='valid'

# %%
class ImageTuple(fastuple):
    @classmethod
    def create(cls, fns): 
        return cls(tuple(PILImage.create(f) for f in fns))
    
    def show(self, ctx=None, **kwargs): 
        t1,t2 = self
        if not isinstance(t1, Tensor) or not isinstance(t2, Tensor) or t1.shape != t2.shape: return ctx
        line = t1.new_zeros(t1.shape[0], t1.shape[1], 10)
        return show_image(torch.cat([t1,line,t2], dim=2), ctx=ctx, **kwargs)

# %%
def ImageTupleBlock(): return TransformBlock(type_tfms=ImageTuple.create, batch_tfms=IntToFloatTensor)

# %%
def get_tuples(files):
    return [[f, Path(str(f).replace('datasetClean','datasetAltura2'))] for f in get_image_files(files)]

# %%
class MyTransform(Transform):
    def __init__(self): self.aug = aug_transforms(size=224,flip_vert=True,max_zoom=1.0)
    def encodes(self, img: PILImage):
        aug_img = self.aug(image=np.array(img))['image']
        return PILImage.create(aug_img)

# %%
def getDataBlock(presize=224,size=224):
    return DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_valid),
                 get_y=get_volumen,
                 item_tfms = [Resize(presize)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
path = Path('../datasetClean/')
trainPath = path/'train'

# %%
db = getDataBlock()
dls = db.dataloaders(trainPath,bs=16)

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    #EarlyStoppingCallback(patience=3),
    SaveModelCallback(fname='convnext_baseVolumeHeightOrtofoto')
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
class SiameseModel(Module):
    def __init__(self, encoder, head):
        self.encoder,self.head = encoder,head
    
    def forward(self, x):
        x1,x2=x
        ftrs = torch.cat([self.encoder(x1), self.encoder(x2)], dim=1)
        return self.head(ftrs)

# %%
model = timm.create_model('convnext_base',num_classes=1,pretrained=True)

# %%
encoder = nn.Sequential(*list(model.children())[:-2])

# %%
head = create_head(int(4096/2), 1, ps=0.5)
model = SiameseModel(encoder, head)

# %%
def siamese_splitter(model):
    return [params(model.encoder), params(model.head)]

# %%
learn = Learner(dls, model,splitter=siamese_splitter,
                loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks).to_fp16()

# %%
# learn.lr_find()

# %%
learn.fine_tune(1000,base_lr=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td
# Better model found at epoch 36 with valid_loss value: 8.445183753967285.
# Better model found at epoch 37 with valid_loss value: 7.070734977722168.
# Better model found at epoch 42 with valid_loss value: 6.660750389099121.
# Better model found at epoch 44 with valid_loss value: 6.2337212562561035.
# Better model found at epoch 45 with valid_loss value: 5.902935028076172.
# Better model found at epoch 46 with valid_loss value: 5.653960704803467.
# Better model found at epoch 50 with valid_loss value: 5.256861686706543.
# Better model found at epoch 52 with valid_loss value: 5.0726823806762695.
# Better model found at epoch 53 with valid_loss value: 4.353168964385986.
# Better model found at epoch 54 with valid_loss value: 4.003119945526123.
# Better model found at epoch 56 with valid_loss value: 3.7903733253479004.
# Better model found at epoch 57 with valid_loss value: 3.7583043575286865.
# Better model found at epoch 58 with valid_loss value: 3.659850835800171.
# Better model found at epoch 60 with valid_loss value: 3.5283265113830566.
# Better model found at epoch 63 with valid_loss value: 2.99224591255188.
# Better model found at epoch 64 with valid_loss value: 2.316864252090454.
# Better model found at epoch 65 with valid_loss value: 2.1759305000305176.
# Better model found at epoch 68 with valid_loss value: 1.978395700454712.
# Better model found at epoch 69 with valid_loss value: 1.9297350645065308.
# Better model found at epoch 70 with valid_loss value: 1.913177728652954.
# Better model found at epoch 71 with valid_loss value: 1.8239833116531372.
# Better model found at epoch 73 with valid_loss value: 1.7457681894302368.
# Better model found at epoch 74 with valid_loss value: 1.372911810874939.
# Better model found at epoch 75 with valid_loss value: 1.179248571395874.
# Better model found at epoch 76 with valid_loss value: 1.1389960050582886.
# Better model found at epoch 79 with valid_loss value: 0.9456556439399719.
# Better model found at epoch 80 with valid_loss value: 0.9329615831375122.
# Better model found at epoch 82 with valid_loss value: 0.9232620000839233.
# Better model found at epoch 83 with valid_loss value: 0.7272074818611145.
# Better model found at epoch 86 with valid_loss value: 0.5641379952430725.
# Better model found at epoch 90 with valid_loss value: 0.5032230615615845.
# Better model found at epoch 114 with valid_loss value: 0.40656551718711853.
# Better model found at epoch 124 with valid_loss value: 0.3903685212135315.
# Better model found at epoch 152 with valid_loss value: 0.32946714758872986.
# Better model found at epoch 200 with valid_loss value: 0.3148403465747833.

# %%
# learn.load('resnetrs50Masav2HeightOrtofotov2')

# %%
# df[df['image_id']=='datasetClean/br_2022-01-07T10-54-11.tif']

# %%
def is_test(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='test'

# %%
dbtest = DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_test),
                 get_y=get_volumen,
                 item_tfms = [Resize(224)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
dlstest = dbtest.dataloaders(path,bs=16)

# %%
learn.dls=dlstest

# %%
learn.validate()
# Out:
# Better model found at epoch 0 with valid_loss value: 0.4792099595069885.
# (#4) [0.46931397914886475,0.4792099595069885,0.685064971446991,0.46931397914886475]

# %%
from sklearn.metrics import mean_absolute_error

# %%
preds,gt = learn.tta()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>

# %%
mean_absolute_error(gt,preds)
# Out:
# 0.4187734
