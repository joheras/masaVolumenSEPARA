# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(0)

# %%
df = pd.read_csv('../dataset.csv')

# %%
df = df.drop(df[df.masa<0].index)

# %%
dftrain = df[(df.split=='train') | (df.split=='valid')]
dftest = df[(df.split=='test')]

# %%
# !mkdir ../datasetAltura/train
# !mkdir ../datasetAltura/test

# %%
# import shutil
# from imutils import paths

# %%
# for image in dftrain.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/train'))

# %%
# for image in dftest.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/test'))

# %%
# df.volumen.describe()

# %%
def get_masa(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['masa'])

def get_volumen(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['volumen'])

def is_valid(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='valid'

# %%
class ImageTuple(fastuple):
    @classmethod
    def create(cls, fns): 
        return cls(tuple(PILImage.create(f) for f in fns))
    
    def show(self, ctx=None, **kwargs): 
        t1,t2 = self
        if not isinstance(t1, Tensor) or not isinstance(t2, Tensor) or t1.shape != t2.shape: return ctx
        line = t1.new_zeros(t1.shape[0], t1.shape[1], 10)
        return show_image(torch.cat([t1,line,t2], dim=2), ctx=ctx, **kwargs)

# %%
def ImageTupleBlock(): return TransformBlock(type_tfms=ImageTuple.create, batch_tfms=IntToFloatTensor)

# %%
def get_tuples(files):
    return [[f, Path(str(f).replace('datasetClean','datasetAltura2'))] for f in get_image_files(files)]

# %%
class MyTransform(Transform):
    def __init__(self): self.aug = aug_transforms(size=224,flip_vert=True,max_zoom=1.0)
    def encodes(self, img: PILImage):
        aug_img = self.aug(image=np.array(img))['image']
        return PILImage.create(aug_img)

# %%
def getDataBlock(presize=224,size=224):
    return DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_valid),
                 get_y=get_masa,
                 item_tfms = [Resize(presize)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
path = Path('../datasetClean/')
trainPath = path/'train'

# %%
db = getDataBlock()
dls = db.dataloaders(trainPath,bs=16)

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    #EarlyStoppingCallback(patience=3),
    SaveModelCallback(fname='convnext_baseMasaHeightOrtofotov2')
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
class SiameseModel(Module):
    def __init__(self, encoder, head):
        self.encoder,self.head = encoder,head
    
    def forward(self, x):
        x1,x2=x
        ftrs = torch.cat([self.encoder(x1), self.encoder(x2)], dim=1)
        return self.head(ftrs)

# %%
model = timm.create_model('convnext_base',num_classes=1,pretrained=True)

# %%
encoder = nn.Sequential(*list(model.children())[:-2])

# %%
head = create_head(int(4096/2), 1, ps=0.5)
model = SiameseModel(encoder, head)

# %%
def siamese_splitter(model):
    return [params(model.encoder), params(model.head)]

# %%
learn = Learner(dls, model,splitter=siamese_splitter,
                loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks).to_fp16()

# %%
# learn.lr_find()

# %%
learn.fine_tune(1000,base_lr=3e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>107871.062500</td>
#       <td>118402.773438</td>
#       <td>307.859558</td>
#       <td>344.097046</td>
#       <td>118402.773438</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 118402.7734375.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>100217.570312</td>
#       <td>114033.734375</td>
#       <td>285.917908</td>
#       <td>337.688812</td>
#       <td>114033.734375</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>97970.445312</td>
#       <td>105396.289062</td>
#       <td>285.331635</td>
#       <td>324.647949</td>
#       <td>105396.289062</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>93978.031250</td>
#       <td>93866.304688</td>
#       <td>273.876648</td>
#       <td>306.376099</td>
#       <td>93866.304688</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>89102.585938</td>
#       <td>88680.585938</td>
#       <td>275.439636</td>
#       <td>297.792847</td>
#       <td>88680.585938</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>83237.031250</td>
#       <td>70189.390625</td>
#       <td>249.093781</td>
#       <td>264.932800</td>
#       <td>70189.390625</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>77561.468750</td>
#       <td>58383.355469</td>
#       <td>229.312820</td>
#       <td>241.626480</td>
#       <td>58383.355469</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>71837.476562</td>
#       <td>65766.156250</td>
#       <td>248.471359</td>
#       <td>256.449127</td>
#       <td>65766.156250</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>65597.500000</td>
#       <td>49516.019531</td>
#       <td>215.773056</td>
#       <td>222.521957</td>
#       <td>49516.019531</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>59265.648438</td>
#       <td>41060.757812</td>
#       <td>196.595871</td>
#       <td>202.634537</td>
#       <td>41060.757812</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>53882.527344</td>
#       <td>37337.503906</td>
#       <td>185.943604</td>
#       <td>193.229141</td>
#       <td>37337.503906</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>48424.222656</td>
#       <td>37929.074219</td>
#       <td>187.975906</td>
#       <td>194.753876</td>
#       <td>37929.074219</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>42999.164062</td>
#       <td>30208.109375</td>
#       <td>165.271652</td>
#       <td>173.804794</td>
#       <td>30208.109375</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>37813.035156</td>
#       <td>18690.576172</td>
#       <td>125.324287</td>
#       <td>136.713486</td>
#       <td>18690.576172</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>32804.335938</td>
#       <td>14548.681641</td>
#       <td>108.441719</td>
#       <td>120.617912</td>
#       <td>14548.681641</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>27861.361328</td>
#       <td>14376.404297</td>
#       <td>106.771103</td>
#       <td>119.901642</td>
#       <td>14376.404297</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>23496.841797</td>
#       <td>5810.906250</td>
#       <td>61.113331</td>
#       <td>76.229301</td>
#       <td>5810.906250</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>19769.960938</td>
#       <td>5838.425293</td>
#       <td>55.809631</td>
#       <td>76.409592</td>
#       <td>5838.425293</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>16329.615234</td>
#       <td>5269.072754</td>
#       <td>56.393196</td>
#       <td>72.588379</td>
#       <td>5269.072754</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td
td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>3713.968018</td>
#       <td>2909.814209</td>
#       <td>42.844952
# Better model found at epoch 0 with valid_loss value: 114033.734375.
# Better model found at epoch 1 with valid_loss value: 105396.2890625.
# Better model found at epoch 2 with valid_loss value: 93866.3046875.
# Better model found at epoch 3 with valid_loss value: 88680.5859375.
# Better model found at epoch 4 with valid_loss value: 70189.390625.
# Better model found at epoch 5 with valid_loss value: 58383.35546875.
# Better model found at epoch 7 with valid_loss value: 49516.01953125.
# Better model found at epoch 8 with valid_loss value: 41060.7578125.
# Better model found at epoch 9 with valid_loss value: 37337.50390625.
# Better model found at epoch 11 with valid_loss value: 30208.109375.
# Better model found at epoch 12 with valid_loss value: 18690.576171875.
# Better model found at epoch 13 with valid_loss value: 14548.681640625.
# Better model found at epoch 14 with valid_loss value: 14376.404296875.
# Better model found at epoch 15 with valid_loss value: 5810.90625.
# Better model found at epoch 17 with valid_loss value: 5269.07275390625.
# Better model found at epoch 18 with valid_loss value: 4298.34716796875.
# Better model found at epoch 19 with valid_loss value: 2908.275634765625.
# Better model found at epoch 22 with valid_loss value: 2512.64111328125.
# Better model found at epoch 25 with valid_loss value: 2488.9453125.
# Better model found at epoch 27 with valid_loss value: 2471.946533203125.
# Better model found at epoch 28 with valid_loss value: 2223.43408203125.
# Better model found at epoch 41 with valid_loss value: 2180.049560546875.
# Better model found at epoch 67 with valid_loss value: 2175.666259765625.
# Better model found at epoch 79 with valid_loss value: 2173.943603515625.
# Better model found at epoch 88 with valid_loss value: 2108.749267578125.
# Better model found at epoch 113 with valid_loss value: 1974.6221923828125.
# Better model found at epoch 114 with valid_loss value: 1907.8563232421875.
# Better model found at epoch 157 with valid_loss value: 1765.089599609375.
# Better model found at epoch 158 with valid_loss value: 1690.1961669921875.
# Better model found at epoch 196 with valid_loss value: 1593.2843017578125.
# Better model found at epoch 250 with valid_loss value: 1590.1025390625.
# Better model found at epoch 266 with valid_loss value: 1548.26953125.
# Better model found at epoch 303 with valid_loss value: 1499.6478271484375.
# Better model found at epoch 334 with valid_loss value: 1420.751708984375.
# Better model found at epoch 437 with valid_loss value: 1400.9036865234375.

# %%
# learn.load('convnext_baseMasaHeightOrtofoto')

# %%
# df[df['image_id']=='datasetClean/br_2022-01-07T10-54-11.tif']

# %%
def is_test(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='test'

# %%
dbtest = DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_test),
                 get_y=get_masa,
                 item_tfms = [Resize(224)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
dlstest = dbtest.dataloaders(path,bs=16)

# %%
learn.dls=dlstest

# %%
learn.validate()
# Out:
# Better model found at epoch 0 with valid_loss value: 31.96142578125.
# (#4) [2334.40625,31.96142578125,48.315696716308594,2334.40625]

# %%
from sklearn.metrics import mean_absolute_error

# %%
preds,gt = learn.tta()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>

# %%
mean_absolute_error(gt,preds)
# Out:
# 31.969593
