# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(0)

# %%
df = pd.read_csv('../dataset.csv')

# %%
df = df.drop(df[df.masa<0].index)

# %%
dftrain = df[(df.split=='train') | (df.split=='valid')]
dftest = df[(df.split=='test')]

# %%
# !mkdir ../datasetAltura/train
# !mkdir ../datasetAltura/test

# %%
# import shutil
# from imutils import paths

# %%
# for image in dftrain.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/train'))

# %%
# for image in dftest.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/test'))

# %%
# df.volumen.describe()

# %%
def get_masa(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['masa'])

def get_volumen(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['volumen'])

def is_valid(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='valid'

# %%
class ImageTuple(fastuple):
    @classmethod
    def create(cls, fns): 
        return cls(tuple(PILImage.create(f) for f in fns))
    
    def show(self, ctx=None, **kwargs): 
        t1,t2 = self
        if not isinstance(t1, Tensor) or not isinstance(t2, Tensor) or t1.shape != t2.shape: return ctx
        line = t1.new_zeros(t1.shape[0], t1.shape[1], 10)
        return show_image(torch.cat([t1,line,t2], dim=2), ctx=ctx, **kwargs)

# %%
def ImageTupleBlock(): return TransformBlock(type_tfms=ImageTuple.create, batch_tfms=IntToFloatTensor)

# %%
def get_tuples(files):
    return [[f, Path(str(f).replace('datasetClean','datasetAltura'))] for f in get_image_files(files)]

# %%
class MyTransform(Transform):
    def __init__(self): self.aug = aug_transforms(size=512,flip_vert=True,max_zoom=1.0)
    def encodes(self, img: PILImage):
        aug_img = self.aug(image=np.array(img))['image']
        return PILImage.create(aug_img)

# %%
def getDataBlock(presize=512,size=512):
    return DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_valid),
                 get_y=get_masa,
                 item_tfms = [Resize(presize)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
path = Path('../datasetClean/')
trainPath = path/'train'

# %%
db = getDataBlock()
dls = db.dataloaders(trainPath,bs=4)

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    #EarlyStoppingCallback(patience=3),
    SaveModelCallback(fname='convnext_baseMasaHeightOrtofoto512')
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
class SiameseModel(Module):
    def __init__(self, encoder, head):
        self.encoder,self.head = encoder,head
    
    def forward(self, x):
        x1,x2=x
        ftrs = torch.cat([self.encoder(x1), self.encoder(x2)], dim=1)
        return self.head(ftrs)

# %%
model = timm.create_model('convnext_base',num_classes=1,pretrained=True)

# %%
encoder = nn.Sequential(*list(model.children())[:-2])

# %%
head = create_head(int(4096/2), 1, ps=0.5)
model = SiameseModel(encoder, head)

# %%
def siamese_splitter(model):
    return [params(model.encoder), params(model.head)]

# %%
learn = Learner(dls, model,splitter=siamese_splitter,
                loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks).to_fp16()

# %%
# learn.lr_find()

# %%
learn.fine_tune(1000,base_lr=1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th
# Better model found at epoch 26 with valid_loss value: 97916.75.
# Better model found at epoch 27 with valid_loss value: 96575.390625.
# Better model found at epoch 32 with valid_loss value: 93710.125.
# Better model found at epoch 33 with valid_loss value: 92428.515625.
# Better model found at epoch 37 with valid_loss value: 82839.2890625.
# Better model found at epoch 40 with valid_loss value: 77317.7734375.
# Better model found at epoch 44 with valid_loss value: 73050.9609375.
# Better model found at epoch 49 with valid_loss value: 71216.2578125.
# Better model found at epoch 51 with valid_loss value: 68857.53125.
# Better model found at epoch 52 with valid_loss value: 61797.33203125.
# Better model found at epoch 59 with valid_loss value: 54016.65625.
# Better model found at epoch 61 with valid_loss value: 50567.16796875.
# Better model found at epoch 62 with valid_loss value: 48001.72265625.
# Better model found at epoch 75 with valid_loss value: 45105.97265625.
# Better model found at epoch 76 with valid_loss value: 42082.60546875.
# Better model found at epoch 77 with valid_loss value: 38841.96484375.
# Better model found at epoch 83 with valid_loss value: 30674.21875.
# Better model found at epoch 86 with valid_loss value: 29949.43359375.
# Better model found at epoch 87 with valid_loss value: 27467.650390625.
# Better model found at epoch 92 with valid_loss value: 26796.376953125.
# Better model found at epoch 93 with valid_loss value: 23642.63671875.
# Better model found at epoch 97 with valid_loss value: 21244.857421875.
# Better model found at epoch 99 with valid_loss value: 17185.765625.
# Better model found at epoch 104 with valid_loss value: 15775.7236328125.
# Better model found at epoch 107 with valid_loss value: 14015.302734375.
# Better model found at epoch 108 with valid_loss value: 8930.70703125.
# Better model found at epoch 110 with valid_loss value: 7409.68115234375.
# Better model found at epoch 114 with valid_loss value: 7379.45361328125.
# Better model found at epoch 117 with valid_loss value: 4858.19384765625.
# Better model found at epoch 121 with valid_loss value: 3990.94482421875.
# Better model found at epoch 167 with valid_loss value: 3642.14697265625.
# Better model found at epoch 215 with valid_loss value: 3418.717041015625.
# Better model found at epoch 239 with valid_loss value: 2715.333740234375.
# Better model found at epoch 532 with valid_loss value: 2374.95361328125.
# Better model found at epoch 714 with valid_loss value: 2299.449951171875.
# Better model found at epoch 766 with valid_loss value: 2141.161865234375.

# %%
learn.load('convnext_baseMasaHeightOrtofoto512')
# Out:
# /home/jonathan/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")

# %%
# df[df['image_id']=='datasetClean/br_2022-01-07T10-54-11.tif']

# %%
def is_test(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='test'

# %%
dbtest = DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_test),
                 get_y=get_masa,
                 item_tfms = [Resize(512)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
dlstest = dbtest.dataloaders(path,bs=8)

# %%
learn.dls=dlstest

# %%
learn.validate()
# Out:
# Better model found at epoch 0 with valid_loss value: 43.61296081542969.
# (#4) [4875.43603515625,43.61296081542969,69.82432556152344,4875.43603515625]

# %%
from sklearn.metrics import mean_absolute_error

# %%
preds,gt = learn.tta()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>

# %%
mean_absolute_error(gt,preds)
# Out:
# 44.630676
