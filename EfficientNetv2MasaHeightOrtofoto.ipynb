# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(1)

# %%
df = pd.read_csv('../dataset.csv')

# %%
df = df.drop(df[df.masa<0].index)

# %%
dftrain = df[(df.split=='train') | (df.split=='valid')]
dftest = df[(df.split=='test')]

# %%
# !mkdir ../datasetAltura/train
# !mkdir ../datasetAltura/test

# %%
# import shutil
# from imutils import paths

# %%
# for image in dftrain.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/train'))

# %%
# for image in dftest.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/test'))

# %%
# df.volumen.describe()

# %%
def get_masa(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['masa'])

def get_volumen(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['volumen'])

def is_valid(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='valid'

# %%
class ImageTuple(fastuple):
    @classmethod
    def create(cls, fns): 
        return cls(tuple(PILImage.create(f) for f in fns))
    
    def show(self, ctx=None, **kwargs): 
        t1,t2 = self
        if not isinstance(t1, Tensor) or not isinstance(t2, Tensor) or t1.shape != t2.shape: return ctx
        line = t1.new_zeros(t1.shape[0], t1.shape[1], 10)
        return show_image(torch.cat([t1,line,t2], dim=2), ctx=ctx, **kwargs)

# %%
def ImageTupleBlock(): return TransformBlock(type_tfms=ImageTuple.create, batch_tfms=IntToFloatTensor)

# %%
def get_tuples(files):
    return [[f, Path(str(f).replace('datasetClean','datasetAltura2'))] for f in get_image_files(files)]

# %%
class MyTransform(Transform):
    def __init__(self): self.aug = aug_transforms(size=224,flip_vert=True,max_zoom=1.0)
    def encodes(self, img: PILImage):
        aug_img = self.aug(image=np.array(img))['image']
        return PILImage.create(aug_img)

# %%
def getDataBlock(presize=224,size=224):
    return DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_valid),
                 get_y=get_masa,
                 item_tfms = [Resize(presize)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
path = Path('../datasetClean/')
trainPath = path/'train'

# %%
db = getDataBlock()
dls = db.dataloaders(trainPath,bs=32)

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    #EarlyStoppingCallback(patience=3),
    SaveModelCallback(fname='efficientnetv2_rw_sMasav2HeightOrtofotov2')
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
class SiameseModel(Module):
    def __init__(self, encoder, head):
        self.encoder,self.head = encoder,head
    
    def forward(self, x):
        x1,x2=x
        ftrs = torch.cat([self.encoder(x1), self.encoder(x2)], dim=1)
        return self.head(ftrs)

# %%
model = timm.create_model('efficientnetv2_rw_s',num_classes=1,pretrained=True)

# %%
encoder = nn.Sequential(*list(model.children())[:-2])

# %%
head = create_head(int(7168/2), 1, ps=0.5)
model = SiameseModel(encoder, head)

# %%
def siamese_splitter(model):
    return [params(model.encoder), params(model.head)]

# %%
learn = Learner(dls, model,splitter=siamese_splitter,
                loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks).to_fp16()

# %%
# learn.lr_find()

# %%
learn.fine_tune(1000,base_lr=3e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th
td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>52861.171875</td>
#       <td>51938.992188</td>
#       <td>208.933273</td>
#       <td>227.901276</td>
#       <td>51938.992188</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>50107.585938</td>
#       <td>47200.699219</td>
#       <td>198.711258</td>
#       <td>217.257202</td>
#       <td>47200.699219</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>47089.433594</td>
#       <td>44406.128906</td>
#       <td>190.957199</td>
#       <td>210.727615</td>
#       <td>44406.128906</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>44086.296875</td>
#       <td>38235.718750</td>
#       <td>173.459763</td>
#       <td>195.539551</td>
#       <td>38235.718750</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>41157.050781</td>
#       <td>38793.054688</td>
#       <td>172.406845</td>
#       <td>196.959518</td>
#       <td>38793.054688</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>38222.390625</td>
#       <td>37829.867188</td>
#       <td>166.637619</td>
#       <td>194.499008</td>
#       <td>37829.867188</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>35535.328125</td>
#       <td>33920.085938</td>
#       <td>154.826385</td>
#       <td>184.174057</td>
#       <td>33920.085938</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>32995.843750</td>
#       <td>30108.402344</td>
#       <td>141.224960</td>
#       <td>173.517731</td>
#       <td>30108.402344</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>30311.763672</td>
#       <td>25865.939453</td>
#       <td>128.372116</td>
#       <td>160.828903</td>
#       <td>25865.939453</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>27703.673828</td>
#       <td>22358.662109</td>
#       <td>114.574295</td>
#       <td>149.528137</td>
#       <td>22358.662109</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>25105.628906</td>
#       <td>24044.474609</td>
#       <td>117.880920</td>
#       <td>155.062790</td>
#       <td>24044.474609</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>22818.312500</td>
#       <td>20518.826172</td>
#       <td>107.514412</td>
#       <td>143.243942</td>
#       <td>20518.826172</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>20571.876953</td>
#       <td>16360.938477</td>
#       <td>95.361717</td>
#       <td>127.909874</td>
#       <td>16360.938477</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>18543.339844</td>
#       <td>14697.629883</td>
#       <td>90.754501</td>
#       <td>121.233772</td>
#       <td>14697.629883</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>16482.365234</td>
#       <td>16032.612305</td>
#       <td>99.118919</td>
#       <td>126.619949</td>
#       <td>16032.612305</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>14749.092773</td>
#       <td>13736.911133</td>
#       <td>94.326500</td>
#       <td>117.204575</td>
#       <td>13736.911133</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>13199.006836</td>
#       <td>12945.385742</td>
#       <td>93.915794</td>
#       <td>113.777802</td>
#       <td>12945.385742
# Better model found at epoch 0 with valid_loss value: 126224.7109375.
# Better model found at epoch 1 with valid_loss value: 126202.9140625.
# Better model found at epoch 2 with valid_loss value: 120052.734375.
# Better model found at epoch 3 with valid_loss value: 119456.0625.
# Better model found at epoch 4 with valid_loss value: 116843.75.
# Better model found at epoch 5 with valid_loss value: 114602.8125.
# Better model found at epoch 6 with valid_loss value: 112637.078125.
# Better model found at epoch 7 with valid_loss value: 109641.9296875.
# Better model found at epoch 8 with valid_loss value: 105586.9140625.
# Better model found at epoch 9 with valid_loss value: 101813.484375.
# Better model found at epoch 10 with valid_loss value: 97894.7109375.
# Better model found at epoch 11 with valid_loss value: 95059.0390625.
# Better model found at epoch 12 with valid_loss value: 88006.1328125.
# Better model found at epoch 13 with valid_loss value: 84397.3125.
# Better model found at epoch 14 with valid_loss value: 79023.390625.
# Better model found at epoch 16 with valid_loss value: 77557.8359375.
# Better model found at epoch 17 with valid_loss value: 72361.3515625.
# Better model found at epoch 18 with valid_loss value: 72213.0546875.
# Better model found at epoch 19 with valid_loss value: 67006.1953125.
# Better model found at epoch 20 with valid_loss value: 63860.20703125.
# Better model found at epoch 21 with valid_loss value: 57890.48046875.
# Better model found at epoch 23 with valid_loss value: 51938.9921875.
# Better model found at epoch 24 with valid_loss value: 47200.69921875.
# Better model found at epoch 25 with valid_loss value: 44406.12890625.
# Better model found at epoch 26 with valid_loss value: 38235.71875.
# Better model found at epoch 28 with valid_loss value: 37829.8671875.
# Better model found at epoch 29 with valid_loss value: 33920.0859375.
# Better model found at epoch 30 with valid_loss value: 30108.40234375.
# Better model found at epoch 31 with valid_loss value: 25865.939453125.
# Better model found at epoch 32 with valid_loss value: 22358.662109375.
# Better model found at epoch 34 with valid_loss value: 20518.826171875.
# Better model found at epoch 35 with valid_loss value: 16360.9384765625.
# Better model found at epoch 36 with valid_loss value: 14697.6298828125.
# Better model found at epoch 38 with valid_loss value: 13736.9111328125.
# Better model found at epoch 39 with valid_loss value: 12945.3857421875.
# Better model found at epoch 41 with valid_loss value: 11732.216796875.
# Better model found at epoch 43 with valid_loss value: 11253.0791015625.
# Better model found at epoch 44 with valid_loss value: 10672.6123046875.
# Better model found at epoch 47 with valid_loss value: 10511.9814453125.
# Better model found at epoch 58 with valid_loss value: 9613.619140625.
# Better model found at epoch 69 with valid_loss value: 8812.33984375.
# Better model found at epoch 78 with valid_loss value: 8802.6748046875.
# Better model found at epoch 79 with valid_loss value: 8682.099609375.
# Better model found at epoch 80 with valid_loss value: 7551.55322265625.
# Better model found at epoch 111 with valid_loss value: 7536.04931640625.
# Better model found at epoch 113 with valid_loss value: 6975.5693359375.
# Better model found at epoch 121 with valid_loss value: 6947.24755859375.
# Better model found at epoch 122 with valid_loss value: 6394.95556640625.
# Better model found at epoch 202 with valid_loss value: 5320.0751953125.
# Better model found at epoch 203 with valid_loss value: 5044.70068359375.
# Better model found at epoch 208 with valid_loss value: 4646.783203125.
# Better model found at epoch 281 with valid_loss value: 4542.44970703125.
# Better model found at epoch 305 with valid_loss value: 4376.2109375.
# Better model found at epoch 336 with valid_loss value: 4127.5390625.
# Better model found at epoch 338 with valid_loss value: 3982.365966796875.
# Better model found at epoch 340 with valid_loss value: 3808.633544921875.
# Better model found at epoch 346 with valid_loss value: 3598.565673828125.
# Better model found at epoch 469 with valid_loss value: 3488.574951171875.
# Better model found at epoch 512 with valid_loss value: 3420.794677734375.
# Better model found at epoch 615 with valid_loss value: 3321.076904296875.

# %%
# learn.load('resnetrs50Masav2HeightOrtofotov2')

# %%
# df[df['image_id']=='datasetClean/br_2022-01-07T10-54-11.tif']

# %%
def is_test(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='test'

# %%
dbtest = DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_test),
                 get_y=get_masa,
                 item_tfms = [Resize(224)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
dlstest = dbtest.dataloaders(path,bs=16)

# %%
learn.dls=dlstest

# %%
learn.validate()
# Out:
# Better model found at epoch 0 with valid_loss value: 51.054141998291016.
# (#4) [4150.7919921875,51.054141998291016,64.4266357421875,4150.7919921875]

# %%
from sklearn.metrics import mean_absolute_error

# %%
preds,gt = learn.tta()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>

# %%
mean_absolute_error(gt,preds)
# Out:
# 51.12178
