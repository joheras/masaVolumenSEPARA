# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(0)

# %%
df = pd.read_csv('../dataset.csv')

# %%
df = df.drop(df[df.masa<0].index)

# %%
dftrain = df[(df.split=='train') | (df.split=='valid')]
dftest = df[(df.split=='test')]

# %%
# !mkdir ../datasetAltura/train
# !mkdir ../datasetAltura/test

# %%
# import shutil
# from imutils import paths

# %%
# for image in dftrain.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/train'))

# %%
# for image in dftest.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/test'))

# %%
# df.volumen.describe()

# %%
def get_masa(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['masa'])

def get_volumen(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['volumen'])

def is_valid(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='valid'

# %%
class ImageTuple(fastuple):
    @classmethod
    def create(cls, fns): 
        return cls(tuple(PILImage.create(f) for f in fns))
    
    def show(self, ctx=None, **kwargs): 
        t1,t2 = self
        if not isinstance(t1, Tensor) or not isinstance(t2, Tensor) or t1.shape != t2.shape: return ctx
        line = t1.new_zeros(t1.shape[0], t1.shape[1], 10)
        return show_image(torch.cat([t1,line,t2], dim=2), ctx=ctx, **kwargs)

# %%
def ImageTupleBlock(): return TransformBlock(type_tfms=ImageTuple.create, batch_tfms=IntToFloatTensor)

# %%
def get_tuples(files):
    return [[f, Path(str(f).replace('datasetClean','datasetAltura'))] for f in get_image_files(files)]

# %%
import albumentations

# %%
class MyTransform(Transform):
    def __init__(self): self.aug = albumentations.Compose([
            albumentations.HueSaturationValue(
                hue_shift_limit=0.2, 
                sat_shift_limit=0.2, 
                val_shift_limit=0.2, 
                p=0.5
            ),
            albumentations.VerticalFlip(p=0.5),
            albumentations.HorizontalFlip(p=0.5),
            albumentations.CoarseDropout(p=0.5),
            albumentations.Cutout(p=0.5)
        ])
    def encodes(self, img: PILImage):
        aug_img = self.aug(image=np.array(img))['image']
        return PILImage.create(aug_img)

# %%
def getDataBlock(presize=224,size=224):
    return DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_valid),
                 get_y=get_masa,
                 item_tfms = [Resize(presize)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
path = Path('../datasetClean/')
trainPath = path/'train'

# %%
db = getDataBlock()
dls = db.dataloaders(trainPath,bs=64)
# Out:
# /home/jonathan/.virtualenvs/segmentation/lib/python3.6/site-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    #EarlyStoppingCallback(patience=3),
    SaveModelCallback(fname='resnet50Masav2HeightOrtofoto')
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
class SiameseModel(Module):
    def __init__(self, encoder, head):
        self.encoder,self.head = encoder,head
    
    def forward(self, x):
        x1,x2=x
# Better model found at epoch 20 with valid_loss value: 114858.2109375.
# Better model found at epoch 21 with valid_loss value: 112818.8515625.
# Better model found at epoch 22 with valid_loss value: 112647.5859375.
# Better model found at epoch 23 with valid_loss value: 111472.140625.
# Better model found at epoch 26 with valid_loss value: 111054.0546875.
# Better model found at epoch 27 with valid_loss value: 110338.8359375.
# Better model found at epoch 28 with valid_loss value: 107704.5234375.
# Better model found at epoch 29 with valid_loss value: 105980.953125.
# Better model found at epoch 30 with valid_loss value: 103957.4609375.
# Better model found at epoch 31 with valid_loss value: 102246.7109375.
# Better model found at epoch 32 with valid_loss value: 98468.1484375.
# Better model found at epoch 33 with valid_loss value: 96017.3359375.
# Better model found at epoch 34 with valid_loss value: 93878.0234375.
# Better model found at epoch 35 with valid_loss value: 93420.6484375.
# Better model found at epoch 37 with valid_loss value: 88315.546875.
# Better model found at epoch 38 with valid_loss value: 81873.5546875.
# Better model found at epoch 39 with valid_loss value: 76189.375.
# Better model found at epoch 40 with valid_loss value: 71923.2890625.
# Better model found at epoch 41 with valid_loss value: 67973.40625.
# Better model found at epoch 42 with valid_loss value: 64678.8515625.
# Better model found at epoch 43 with valid_loss value: 61839.60546875.
# Better model found at epoch 45 with valid_loss value: 61123.10546875.
# Better model found at epoch 46 with valid_loss value: 60770.34375.
# Better model found at epoch 49 with valid_loss value: 59669.97265625.
# Better model found at epoch 50 with valid_loss value: 56775.1015625.
# Better model found at epoch 51 with valid_loss value: 54162.3828125.
# Better model found at epoch 52 with valid_loss value: 52976.01953125.
# Better model found at epoch 53 with valid_loss value: 51409.9921875.
# Better model found at epoch 54 with valid_loss value: 50826.88671875.
# Better model found at epoch 55 with valid_loss value: 50386.58984375.
# Better model found at epoch 56 with valid_loss value: 49049.70703125.
# Better model found at epoch 57 with valid_loss value: 46142.3203125.
# Better model found at epoch 58 with valid_loss value: 43536.6875.
# Better model found at epoch 59 with valid_loss value: 41776.75.
# Better model found at epoch 60 with valid_loss value: 40612.15234375.
# Better model found at epoch 61 with valid_loss value: 40177.60546875.
# Better model found at epoch 62 with valid_loss value: 38900.5625.
# Better model found at epoch 63 with valid_loss value: 37574.38671875.
# Better model found at epoch 64 with valid_loss value: 36117.7890625.
# Better model found at epoch 65 with valid_loss value: 34534.30859375.
# Better model found at epoch 66 with valid_loss value: 33749.53125.
# Better model found at epoch 68 with valid_loss value: 33196.23046875.
# Better model found at epoch 69 with valid_loss value: 32594.89453125.
# Better model found at epoch 70 with valid_loss value: 31348.037109375.
# Better model found at epoch 71 with valid_loss value: 30123.177734375.
# Better model found at epoch 72 with valid_loss value: 28179.39453125.
# Better model found at epoch 73 with valid_loss value: 26498.462890625.
# Better model found at epoch 74 with valid_loss value: 25698.701171875.
# Better model found at epoch 75 with valid_loss value: 25679.521484375.
# Better model found at epoch 77 with valid_loss value: 25374.88671875.
# Better model found at epoch 78 with valid_loss value: 24875.095703125.
# Better model found at epoch 79 with valid_loss value: 23784.76953125.
# Better model found at epoch 80 with valid_loss value: 22940.419921875.
# Better model found at epoch 81 with valid_loss value: 22514.341796875.
# Better model found at epoch 82 with valid_loss value: 21930.689453125.
# Better model found at epoch 83 with valid_loss value: 20861.037109375.
# Better model found at epoch 84 with valid_loss value: 20139.255859375.
# Better model found at epoch 86 with valid_loss value: 19750.974609375.
# Better model found at epoch 87 with valid_loss value: 19652.060546875.
# Better model found at epoch 90 with valid_loss value: 18364.69140625.
# Better model found at epoch 91 with valid_loss value: 17497.2734375.
# Better model found at epoch 92 with valid_loss value: 16299.7451171875.
# Better model found at epoch 93 with valid_loss value: 16056.9638671875.
# Better model found at epoch 94 with valid_loss value: 15908.259765625.
# Better model found at epoch 95 with valid_loss value: 15903.1171875.
# Better model found at epoch 103 with valid_loss value: 14996.1064453125.
# Better model found at epoch 119 with valid_loss value: 13975.2841796875.
# Better model found at epoch 164 with valid_loss value: 13423.4013671875.
# Better model found at epoch 165 with valid_loss value: 12702.4287109375.
# Better model found at epoch 166 with valid_loss value: 12138.0556640625.
# Better model found at epoch 167 with valid_loss value: 11909.2236328125.
# Better model found at epoch 168 with valid_loss value: 11905.9599609375.
# Better model found at epoch 172 with valid_loss value: 11117.1982421875.
# Better model found at epoch 173 with valid_loss value: 10146.212890625.
# Better model found at epoch 221 with valid_loss value: 9127.8447265625.
# Better model found at epoch 222 with valid_loss value: 8181.6298828125.
# Better model found at epoch 227 with valid_loss value: 7688.08056640625.
# Better model found at epoch 228 with valid_loss value: 7452.5517578125.
# Better model found at epoch 331 with valid_loss value: 7139.45556640625.
# Better model found at epoch 346 with valid_loss value: 6976.62841796875.
# Better model found at epoch 347 with valid_loss value: 6133.59716796875.
# Better model found at epoch 366 with valid_loss value: 5481.05712890625.
# Better model found at epoch 447 with valid_loss value: 5448.87255859375.
# Better model found at epoch 448 with valid_loss value: 5013.39794921875.
# Better model found at epoch 454 with valid_loss value: 4414.08154296875.
# Better model found at epoch 566 with valid_loss value: 4050.34814453125.
# Better model found at epoch 585 with valid_loss value: 3415.214111328125.
# Better model found at epoch 640 with valid_loss value: 3411.010986328125.
# Better model found at epoch 655 with valid_loss value: 3306.855224609375.
# Better model found at epoch 656 with valid_loss value: 2768.553466796875.
# Better model found at epoch 965 with valid_loss value: 2726.08154296875.
# Better model found at epoch 976 with valid_loss value: 2502.72216796875.
# Better model found at epoch 984 with valid_loss value: 2392.407958984375.

# %%
learn.load('resnet50Masav2HeightOrtofoto')
# Out:
# /home/jonathan/.virtualenvs/segmentation/lib/python3.6/site-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")

# %%
def is_test(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='test'

# %%
dbtest = DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_test),
                 get_y=get_masa,
                 item_tfms = [Resize(224)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
dlstest = dbtest.dataloaders(path,bs=16)

# %%
learn.dls=dlstest

# %%
learn.validate()
# Out:
# Better model found at epoch 0 with valid_loss value: 47.85129165649414.
# (#4) [4951.11376953125,47.85129165649414,70.36415100097656,4951.11376953125]

# %%
from sklearn.metrics import mean_absolute_error

# %%
preds,gt = learn.tta()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>

# %%
mean_absolute_error(gt,preds)
# Out:
# 49.103474
