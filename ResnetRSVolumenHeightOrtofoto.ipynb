# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(1)

# %%
df = pd.read_csv('../dataset.csv')

# %%
df = df.drop(df[df.masa<0].index)

# %%
dftrain = df[(df.split=='train') | (df.split=='valid')]
dftest = df[(df.split=='test')]

# %%
# !mkdir ../datasetAltura/train
# !mkdir ../datasetAltura/test

# %%
# import shutil
# from imutils import paths

# %%
# for image in dftrain.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/train'))

# %%
# for image in dftest.image_id.values:
#     shutil.move(image.replace('datasetClean','../datasetAltura'),
#                 image.replace('datasetClean','../datasetAltura/test'))

# %%
# df.volumen.describe()

# %%
def get_masa(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['masa'])

def get_volumen(f):
    f = f[0]
    return float(df[df['image_id']=='datasetClean/'+f.name]['volumen'])

def is_valid(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='valid'

# %%
class ImageTuple(fastuple):
    @classmethod
    def create(cls, fns): 
        return cls(tuple(PILImage.create(f) for f in fns))
    
    def show(self, ctx=None, **kwargs): 
        t1,t2 = self
        if not isinstance(t1, Tensor) or not isinstance(t2, Tensor) or t1.shape != t2.shape: return ctx
        line = t1.new_zeros(t1.shape[0], t1.shape[1], 10)
        return show_image(torch.cat([t1,line,t2], dim=2), ctx=ctx, **kwargs)

# %%
def ImageTupleBlock(): return TransformBlock(type_tfms=ImageTuple.create, batch_tfms=IntToFloatTensor)

# %%
def get_tuples(files):
    return [[f, Path(str(f).replace('datasetClean','datasetAltura2'))] for f in get_image_files(files)]

# %%
class MyTransform(Transform):
    def __init__(self): self.aug = aug_transforms(size=224,flip_vert=True,max_zoom=1.0)
    def encodes(self, img: PILImage):
        aug_img = self.aug(image=np.array(img))['image']
        return PILImage.create(aug_img)

# %%
def getDataBlock(presize=224,size=224):
    return DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_valid),
                 get_y=get_volumen,
                 item_tfms = [Resize(presize)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
path = Path('../datasetClean/')
trainPath = path/'train'

# %%
db = getDataBlock()
dls = db.dataloaders(trainPath,bs=64)

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    #EarlyStoppingCallback(patience=3),
    SaveModelCallback(fname='resnetrs50VolumeHeightOrtofoto')
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
class SiameseModel(Module):
    def __init__(self, encoder, head):
        self.encoder,self.head = encoder,head
    
    def forward(self, x):
        x1,x2=x
        ftrs = torch.cat([self.encoder(x1), self.encoder(x2)], dim=1)
        return self.head(ftrs)

# %%
model = timm.create_model('resnetrs50',num_classes=1,pretrained=True)

# %%
encoder = nn.Sequential(*list(model.children())[:-2])

# %%
head = create_head(4096, 1, ps=0.5)
model = SiameseModel(encoder, head)

# %%
def siamese_splitter(model):
    return [params(model.encoder), params(model.head)]

# %%
learn = Learner(dls, model,splitter=siamese_splitter,
                loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks).to_fp16()

# %%
# learn.lr_find()

# %%
learn.fine_tune(1000,base_lr=3e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th
td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>3.227202</td>
#       <td>7.376789</td>
#       <td>2.176477</td>
#       <td>2.716025</td>
#       <td>7.376789</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>43</td>
# Better model found at epoch 0 with valid_loss value: 24.025163650512695.
# Better model found at epoch 3 with valid_loss value: 18.178390502929688.
# Better model found at epoch 4 with valid_loss value: 17.788558959960938.
# Better model found at epoch 7 with valid_loss value: 16.056941986083984.
# Better model found at epoch 8 with valid_loss value: 14.279276847839355.
# Better model found at epoch 9 with valid_loss value: 13.335909843444824.
# Better model found at epoch 17 with valid_loss value: 12.374789237976074.
# Better model found at epoch 18 with valid_loss value: 11.280499458312988.
# Better model found at epoch 19 with valid_loss value: 10.48298168182373.
# Better model found at epoch 20 with valid_loss value: 9.537020683288574.
# Better model found at epoch 21 with valid_loss value: 9.021371841430664.
# Better model found at epoch 22 with valid_loss value: 8.406686782836914.
# Better model found at epoch 23 with valid_loss value: 7.7553391456604.
# Better model found at epoch 24 with valid_loss value: 7.096102714538574.
# Better model found at epoch 25 with valid_loss value: 6.380849361419678.
# Better model found at epoch 26 with valid_loss value: 5.811903476715088.
# Better model found at epoch 27 with valid_loss value: 5.4720354080200195.
# Better model found at epoch 28 with valid_loss value: 5.347647666931152.
# Better model found at epoch 32 with valid_loss value: 5.250812530517578.
# Better model found at epoch 33 with valid_loss value: 5.189176082611084.
# Better model found at epoch 71 with valid_loss value: 4.832858562469482.
# Better model found at epoch 113 with valid_loss value: 4.660280704498291.
# Better model found at epoch 114 with valid_loss value: 4.640525817871094.
# Better model found at epoch 115 with valid_loss value: 4.535805702209473.
# Better model found at epoch 118 with valid_loss value: 3.81483793258667.
# Better model found at epoch 130 with valid_loss value: 3.5957095623016357.
# Better model found at epoch 132 with valid_loss value: 3.574312686920166.
# Better model found at epoch 157 with valid_loss value: 3.3269622325897217.
# Better model found at epoch 176 with valid_loss value: 3.2587034702301025.
# Better model found at epoch 194 with valid_loss value: 2.9702041149139404.
# Better model found at epoch 216 with valid_loss value: 2.872615337371826.
# Better model found at epoch 218 with valid_loss value: 2.3326938152313232.
# Better model found at epoch 222 with valid_loss value: 2.030907154083252.
# Better model found at epoch 242 with valid_loss value: 1.573667287826538.
# Better model found at epoch 276 with valid_loss value: 1.1756131649017334.
# Better model found at epoch 360 with valid_loss value: 1.1498724222183228.
# Better model found at epoch 363 with valid_loss value: 0.9530099034309387.

# %%
# learn.load('resnetrs50Masav2HeightOrtofotov2')

# %%
# df[df['image_id']=='datasetClean/br_2022-01-07T10-54-11.tif']

# %%
def is_test(f):
    f = f[0]
    return (df[df['image_id']=='datasetClean/'+f.name]['split']).values[0]=='test'

# %%
dbtest = DataBlock(blocks = (ImageTupleBlock, RegressionBlock()),
                 get_items=get_tuples, 
                 splitter=FuncSplitter(is_test),
                 get_y=get_volumen,
                 item_tfms = [Resize(224)],
                 batch_tfms=[MyTransform(),Normalize.from_stats(*imagenet_stats)])

# %%
dlstest = dbtest.dataloaders(path,bs=16)

# %%
learn.dls=dlstest

# %%
learn.validate()
# Out:
# Better model found at epoch 0 with valid_loss value: 0.850374162197113.
# (#4) [1.2030866146087646,0.850374162197113,1.0968530178070068,1.2030866146087646]

# %%
from sklearn.metrics import mean_absolute_error

# %%
preds,gt = learn.tta()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>

# %%
mean_absolute_error(gt,preds)
# Out:
# 0.8516422
